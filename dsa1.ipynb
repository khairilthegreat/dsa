# %%
import pandas as pd

# %%
google_play_apps = pd.read_csv('googleplaystore.csv')

# %%
google_play_apps.shape
# Out:
# (10841, 13)

# %%
google_play_apps.Category.nunique(dropna = True)
# Out:
# 34

# %%
google_play_apps.Genres.nunique(dropna = True)
# Out:
# 120

# %%
google_play_apps.drop_duplicates(subset='App', inplace=True)

# %%
google_play_apps[google_play_apps['Installs']=='Free']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
google_play_apps['Installs'] = google_play_apps['Installs'].apply(lambda x: x.replace(',', '') if ',' in str(x) else x)

# %%
google_play_apps['Installs'] = google_play_apps['Installs'].apply(lambda x: x.replace('+', '') if '+' in str(x) else x)

# %%
google_play_apps.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size Installs  Type Price Content Rating                     Genres  \
# 0     159  19M    10000  Free     0       Everyone               Art & Design
# 1     967  14M   500000  Free     0       Everyone  Art & Design;Pretend Play
#
#        Last Updated Current Ver   Android Ver
# 0   January 7, 2018       1.0.0  4.0.3 and up
# 1  January 15, 2018       2.0.0  4.0.3 and up

# %%
google_play_apps = google_play_apps[google_play_apps['Installs'] != 'Free']

# %%
google_play_apps['Installs'] = google_play_apps['Installs'].astype(int)

# %%
google_play_apps['Reviews'] = google_play_apps['Reviews'].apply(lambda x: x.replace('+', '') if '+' in str(x) else x)

# %%
google_play_apps['Reviews'] = google_play_apps['Reviews'].apply(lambda x: x.replace(',', '') if ',' in str(x) else x)

# %%
google_play_apps['Reviews'] = google_play_apps['Reviews'].astype(int)

# %%
google_play_apps.sort_values(by=['Reviews'], ascending=False)
# Out:
#                                            App         Category  Rating  \
# 2544                                  Facebook           SOCIAL     4.1
# 336                         WhatsApp Messenger    COMMUNICATION     4.4
# 2545                                 Instagram           SOCIAL     4.5
# 335   Messenger – Text and Video Chat for Free    COMMUNICATION     4.0
# 1670                            Clash of Clans             GAME     4.6
# ...                                        ...              ...     ...
# 6225                      BH Bikes GPS Locator           SPORTS     NaN
# 6880                            BV Teknisk App         BUSINESS     NaN
# 6153            BG MUSIC PLAYER - MUSIC PLAYER    VIDEO_PLAYERS     NaN
# 8154                       Wallpapers CZ 75 85  PERSONALIZATION     NaN
# 8612                                 DN Snacks         BUSINESS     NaN
#
#        Reviews                Size    Installs  Type Price Content Rating  \
# ...

# %%
g2 = google_play_apps[google_play_apps['App'].str.contains("(?i)candy|temple|subway|talking")]

# %%
g2[['App','Category','Rating','Installs','Reviews']].sort_values(by=['Installs', 'Rating'],ascending=[False,False]).head()
# Out:
#                        App Category  Rating    Installs   Reviews
# 1654        Subway Surfers     GAME     4.5  1000000000  27722264
# 1722        My Talking Tom     GAME     4.5   500000000  14891223
# 1655      Candy Crush Saga     GAME     4.4   500000000  22426677
# 1661          Temple Run 2     GAME     4.3   500000000   8118609
# 1737  Talking Tom Gold Run     GAME     4.6   100000000   2698348

# %%
g1 = google_play_apps[google_play_apps['App'].str.contains("(?i)whatsapp|bbm|viber|line|skype")]

# %%
g1[['App','Category','Rating','Installs','Reviews']].sort_values(by=['Reviews'],ascending=[False]).head()
# Out:
#                                App       Category  Rating    Installs  \
# 336             WhatsApp Messenger  COMMUNICATION     4.4  1000000000
# 406    BBM - Free Calls & Messages  COMMUNICATION     4.3   100000000
# 342                Viber Messenger  COMMUNICATION     4.3   500000000
# 403    LINE: Free Calls & Messages  COMMUNICATION     4.2   500000000
# 391  Skype - free IM & video calls  COMMUNICATION     4.1  1000000000
#
#       Reviews
# 336  69119316
# 406  12842860
# 342  11334799
# 403  10790289
# 391  10484169

# %%
g0 = google_play_apps[google_play_apps['App'].str.contains("(?i)File Commander|pinterest|FIFA Soccer|Whatsapp|Dropbox|Subway Surfers|Flipboard|DU Battery")]

# %%
g0[['App','Category']]
# Out:
#                                                      App            Category
# 336                                   WhatsApp Messenger       COMMUNICATION
# 367                                    WhatsApp Business       COMMUNICATION
# 1654                                      Subway Surfers                GAME
# 2552                                           Pinterest              SOCIAL
# 3473                                             Dropbox        PRODUCTIVITY
# 3755                        Flipboard: News For Our Time  NEWS_AND_MAGAZINES
# 4734                    Open in WhatsApp (click to chat)               TOOLS
# 6093                           Funny videos for whatsapp       VIDEO_PLAYERS
# 8445                                         FIFA Soccer              SPORTS
# 8546                                     DM for WhatsApp       COMMUNICATION
# 8675                                     Dp For WhatsApp     PERSONALIZATION
# ...

# %%
google_play_apps[['App','Category','Rating','Installs','Reviews']].sort_values(by=['Installs'],ascending=[False]).head(20)
# Out:
#                                            App             Category  Rating  \
# 336                         WhatsApp Messenger        COMMUNICATION     4.4
# 152                          Google Play Books  BOOKS_AND_REFERENCE     3.9
# 1654                            Subway Surfers                 GAME     4.5
# 3117                 Maps - Navigate & Explore     TRAVEL_AND_LOCAL     4.3
# 340                                      Gmail        COMMUNICATION     4.3
# 2545                                 Instagram               SOCIAL     4.5
# 2544                                  Facebook               SOCIAL     4.1
# 338               Google Chrome: Fast & Secure        COMMUNICATION     4.3
# 2554                                   Google+               SOCIAL     4.2
# 3665                                   YouTube        VIDEO_PLAYERS     4.3
# 3127                        Google Street View     TRAVEL_AND_LOCAL     4.2
# ...

# %%
google_play_apps[google_play_apps['App'].str.contains("(?i)google duo")]
# Out:
#                                        App       Category  Rating  Reviews  \
# 371  Google Duo - High Quality Video Calls  COMMUNICATION     4.6  2083237
#
#                    Size   Installs  Type Price Content Rating         Genres  \
# 371  Varies with device  500000000  Free     0       Everyone  Communication
#
#       Last Updated               Current Ver Android Ver
# 371  July 31, 2018  37.1.206017801.DR37_RC14  4.4 and up
